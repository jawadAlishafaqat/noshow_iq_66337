# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Computer Arena\\OneDrive\\Desktop\\MID PAPER\\noshow_iq_66337\\data\\dataset.csv')

# %%
print(df.shape)
# Out:
# (110527, 14)

# %%
print(df.columns.tolist())
# Out:
# ['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay', 'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension', 'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'No-show']

# %%
print(df['No-show'].value_counts(normalize=True))
# Out:
# No-show
# No     0.798067
# Yes    0.201933
# Name: proportion, dtype: float64

# %%
print(df['Age'].describe())
# Out:
# count    110527.000000
# mean         37.088874
# std          23.110205
# min          -1.000000
# 25%          18.000000
# 50%          37.000000
# 75%          55.000000
# max         115.000000
# Name: Age, dtype: float64

# %%
# Training script — notebooks/01_eda.ipynb mein run karo
import sys
sys.path.insert(0, '..')
from noshow_iq.preprocess import load_raw, prepare
from noshow_iq import model

df = load_raw('C:\\Users\\Computer Arena\\OneDrive\\Desktop\\MID PAPER\\noshow_iq_66337\\data\\dataset.csv)
X, y = prepare(df)
clf, metrics = model.train(X, y, save=True)
print(metrics['report'])
# Out:
#   Cell In[15], line 7
#     df = load_raw('C:\\Users\\Computer Arena\\OneDrive\\Desktop\\MID PAPER\\noshow_iq_66337\\data\\dataset.csv)
#                   ^
# SyntaxError: unterminated string literal (detected at line 7)
